# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W  2.0  0.0
# 2  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  0.0
# 3  2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D  3.0  3.0
# 4  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W  4.0  2.0
# 5  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  6.0  0.0
#
#           opponent  ...  match report  notes    sh   sot  dist   fk   pk  \
# 1         West Ham  ...  Match Report    NaN  13.0   1.0  18.7  1.0  1.0
# 2      Bournemouth  ...  Match Report    NaN  19.0   7.0  17.5  0.0  0.0
# 3    Newcastle Utd  ...  Match Report    NaN  21.0  10.0  16.2  1.0  0.0
# 4   Crystal Palace  ...  Match Report    NaN  18.0   5.0  14.1  0.0  0.0
# 5  Nott'ham Forest  ...  Match Report    NaN  17.0   9.0  14.8  0.0  0.0
#
#   pkatt  season             team
# 1   1.0    2023  Manchester City
# 2   0.0    2023  Manchester City
# 3   0.0    2023  Manchester City
# 4   0.0    2023  Manchester City
# 5   0.0    2023  Manchester City
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (2280, 27)

# %%
# Missing Liverpool 2021-2022
matches["team"].value_counts()
# Out:
# Manchester City             114
# Crystal Palace              114
# Southampton                 114
# Leeds United                114
# Leicester City              114
# Everton                     114
# West Ham United             114
# Arsenal                     114
# Chelsea                     114
# Wolverhampton Wanderers     114
# Tottenham Hotspur           114
# Aston Villa                 114
# Brighton and Hove Albion    114
# Liverpool                   114
# Newcastle United            114
# Manchester United           114
# Fulham                       76
# Brentford                    76
# Burnley                      76
# Bournemouth                  38
# Nottingham Forest            38
# Watford                      38
# Norwich City                 38
# West Bromwich Albion         38
# Sheffield United             38
# Name: team, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W  4.0
# 2   2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away      W  2.0
# 4   2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home      W  3.0
# 6   2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L  2.0
# 7   2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D  2.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 47  2023-05-03  20:00  Premier League  Matchweek 28  Wed  Home      W  1.0
# 48  2023-05-06  17:30  Premier League  Matchweek 35  Sat  Home      W  1.0
# 49  2023-05-15  20:00  Premier League  Matchweek 36  Mon  Away      W  3.0
# 50  2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D  1.0
# 51  2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      D  4.0
#
#      ga        opponent  ...  match report  notes    sh  sot  dist   fk   pk  \
# 1   3.0    Leeds United  ...  Match Report    NaN  20.0  4.0  18.4  0.0  2.0
# 2   0.0         Chelsea  ...  Match Report    NaN  18.0  5.0  18.2  1.0  0.0
# 4   1.0         Arsenal  ...  Match Report    NaN  21.0  8.0  17.9  0.0  0.0
# 6   7.0     Aston Villa  ...  Match Report    NaN  14.0  8.0  16.3  1.0  0.0
# 7   2.0         Everton  ...  Match Report    NaN  22.0  8.0  16.0  2.0  0.0
# ..  ...             ...  ...           ...    ...   ...  ...   ...  ...  ...
# 47  0.0          Fulham  ...  Match Report    NaN  14.0  2.0  22.6  0.0  1.0
# 48  0.0       Brentford  ...  Match Report    NaN  15.0  5.0  18.8  0.0  0.0
# 49  0.0  Leicester City  ...  Match Report    NaN  16.0  5.0  17.5  1.0  0.0
# 50  1.0     Aston Villa  ...  Match Report    NaN  10.0  5.0  18.2  0.0  0.0
# 51  4.0     Southampton  ...  Match Report    NaN  30.0  8.0  18.5  0.0  0.0
#
#    pkatt  season       team
# 1    2.0    2021  Liverpool
# 2    0.0    2021  Liverpool
# 4    0.0    2021  Liverpool
# 6    0.0    2021  Liverpool
# 7    0.0    2021  Liverpool
# ..   ...     ...        ...
# 47   1.0    2023  Liverpool
# 48   0.0    2023  Liverpool
# 49   0.0    2023  Liverpool
# 50   0.0    2023  Liverpool
# 51   0.0    2023  Liverpool
#
# [114 rows x 27 columns]

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     60
# Matchweek 30    60
# Matchweek 23    60
# Matchweek 12    60
# Matchweek 24    60
# Matchweek 25    60
# Matchweek 26    60
# Matchweek 27    60
# Matchweek 29    60
# Matchweek 31    60
# Matchweek 2     60
# Matchweek 33    60
# Matchweek 34    60
# Matchweek 28    60
# Matchweek 35    60
# Matchweek 36    60
# Matchweek 37    60
# Matchweek 32    60
# Matchweek 22    60
# Matchweek 21    60
# Matchweek 7     60
# Matchweek 20    60
# Matchweek 3     60
# Matchweek 4     60
# Matchweek 5     60
# Matchweek 6     60
# Matchweek 8     60
# Matchweek 9     60
# Matchweek 10    60
# Matchweek 11    60
# Matchweek 13    60
# Matchweek 14    60
# Matchweek 15    60
# Matchweek 16    60
# Matchweek 17    60
# Matchweek 18    60
# Matchweek 19    60
# Matchweek 38    60
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %% [markdown]
# ## Feature Engineering

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 1  2022-08-07  16:30   Matchweek 1  Sun  Away      W  2.0  0.0
# 2  2022-08-13  15:00   Matchweek 2  Sat  Home      W  4.0  0.0
# 3  2022-08-21  16:30   Matchweek 3  Sun  Away      D  3.0  3.0
# 4  2022-08-27  15:00   Matchweek 4  Sat  Home      W  4.0  2.0
# 5  2022-08-31  19:30   Matchweek 5  Wed  Home      W  6.0  0.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 38 2021-05-02  19:15  Matchweek 34  Sun  Away      L  0.0  4.0
# 39 2021-05-08  15:00  Matchweek 35  Sat  Home      L  0.0  2.0
# 40 2021-05-16  19:00  Matchweek 36  Sun  Away      W  1.0  0.0
# 41 2021-05-19  18:00  Matchweek 37  Wed  Away      L  0.0  1.0
# 42 2021-05-23  16:00  Matchweek 38  Sun  Home      W  1.0  0.0
#
#            opponent   xg  ...  match report    sh   sot  dist   fk   pk pkatt  \
# 1          West Ham  2.2  ...  Match Report  13.0   1.0  18.7  1.0  1.0   1.0
# 2       Bournemouth  1.7  ...  Match Report  19.0   7.0  17.5  0.0  0.0   0.0
# 3     Newcastle Utd  2.1  ...  Match Report  21.0  10.0  16.2  1.0  0.0   0.0
# 4    Crystal Palace  2.2  ...  Match Report  18.0   5.0  14.1  0.0  0.0   0.0
# 5   Nott'ham Forest  3.3  ...  Match Report  17.0   9.0  14.8  0.0  0.0   0.0
# ..              ...  ...  ...           ...   ...   ...   ...  ...  ...   ...
# 38        Tottenham  0.5  ...  Match Report   8.0   1.0  18.2  0.0  0.0   0.0
# 39   Crystal Palace  0.7  ...  Match Report   7.0   0.0  13.4  1.0  0.0   0.0
# 40          Everton  1.2  ...  Match Report  10.0   3.0  18.5  0.0  0.0   0.0
# 41    Newcastle Utd  0.9  ...  Match Report  11.0   1.0  18.3  1.0  0.0   0.0
# 42          Burnley  0.5  ...  Match Report  12.0   3.0  17.4  0.0  0.0   0.0
#
#     season              team  target
# 1     2023   Manchester City       1
# 2     2023   Manchester City       1
# 3     2023   Manchester City       0
# 4     2023   Manchester City       1
# 5     2023   Manchester City       1
# ..     ...               ...     ...
# 38    2021  Sheffield United       0
# 39    2021  Sheffield United       0
# 40    2021  Sheffield United       1
# 41    2021  Sheffield United       0
# 42    2021  Sheffield United       1
#
# [2280 rows x 26 columns]

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 1  2022-08-07  16:30   Matchweek 1  Sun  Away      W  2.0  0.0
# 2  2022-08-13  15:00   Matchweek 2  Sat  Home      W  4.0  0.0
# 3  2022-08-21  16:30   Matchweek 3  Sun  Away      D  3.0  3.0
# 4  2022-08-27  15:00   Matchweek 4  Sat  Home      W  4.0  2.0
# 5  2022-08-31  19:30   Matchweek 5  Wed  Home      W  6.0  0.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 38 2021-05-02  19:15  Matchweek 34  Sun  Away      L  0.0  4.0
# 39 2021-05-08  15:00  Matchweek 35  Sat  Home      L  0.0  2.0
# 40 2021-05-16  19:00  Matchweek 36  Sun  Away      W  1.0  0.0
# 41 2021-05-19  18:00  Matchweek 37  Wed  Away      L  0.0  1.0
# 42 2021-05-23  16:00  Matchweek 38  Sun  Home      W  1.0  0.0
#
#            opponent   xg  ...   fk   pk  pkatt season              team  \
# 1          West Ham  2.2  ...  1.0  1.0    1.0   2023   Manchester City
# 2       Bournemouth  1.7  ...  0.0  0.0    0.0   2023   Manchester City
# 3     Newcastle Utd  2.1  ...  1.0  0.0    0.0   2023   Manchester City
# 4    Crystal Palace  2.2  ...  0.0  0.0    0.0   2023   Manchester City
# 5   Nott'ham Forest  3.3  ...  0.0  0.0    0.0   2023   Manchester City
# ..              ...  ...  ...  ...  ...    ...    ...               ...
# 38        Tottenham  0.5  ...  0.0  0.0    0.0   2021  Sheffield United
# 39   Crystal Palace  0.7  ...  1.0  0.0    0.0   2021  Sheffield United
# 40          Everton  1.2  ...  0.0  0.0    0.0   2021  Sheffield United
# 41    Newcastle Utd  0.9  ...  1.0  0.0    0.0   2021  Sheffield United
# 42          Burnley  0.5  ...  0.0  0.0    0.0   2021  Sheffield United
#
#    target venue_code  opp_code  hour  day_code
# 1       1          0        23    16         6
# 2       1          1         2    15         5
# 3       0          0        15    16         6
# 4       1          1         7    15         5
# 5       1          1        17    19         2
# ..    ...        ...       ...   ...       ...
# 38      0          0        20    19         6
# 39      0          1         7    15         5
# 40      1          0         8    19         6
# 41      0          0        15    18         2
# 42      1          1         5    16         6
#
# [2280 rows x 30 columns]

# %%
predictor = ["venue_code", "opp_code", "hour", "day_code", "target"]
subset = matches[predictor]
# Calculate the correlation matrix
correlation_matrix = subset.corr()

# Generate the correlation heatmap
sns.heatmap(correlation_matrix, annot=True, cmap="YlGnBu")

# Set the plot title
plt.title('Correlation Heatmap')

# Display the plot
plt.show()

# %% [markdown]
# ## Model building
#
# Training a model on few predictors

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2023-01-01']

# %%
test = matches[matches["date"] > '2023-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
error = accuracy_score(test["target"], preds)

# %%
error
# Out:
# 0.6004672897196262

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          208  55
# 1          116  49

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.47115384615384615

# %%
from sklearn.metrics import confusion_matrix
cf_matrix = confusion_matrix(test["target"],preds)
sns.heatmap(cf_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
k=KNeighborsClassifier()

# %%
k.fit(train[predictors], train["target"])
# Out:
# KNeighborsClassifier()

# %%
preds = k.predict(test[predictors])

# %%
error = accuracy_score(test["target"], preds)
error
# Out:
# 0.5864485981308412

# %%
precision_score(test["target"], preds)
# Out:
# 0.44339622641509435

# %%
cf_matrix = confusion_matrix(test["target"],preds)
sns.heatmap(cf_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Improving precision with rolling averages

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time         round  day venue result   gf   ga       opponent  \
# 5  2020-10-17  17:30   Matchweek 5  Sat  Home      W  1.0  0.0        Arsenal
# 7  2020-10-24  12:30   Matchweek 6  Sat  Away      D  1.0  1.0       West Ham
# 9  2020-10-31  12:30   Matchweek 7  Sat  Away      W  1.0  0.0  Sheffield Utd
# 11 2020-11-08  16:30   Matchweek 8  Sun  Home      D  1.0  1.0      Liverpool
# 12 2020-11-21  17:30   Matchweek 9  Sat  Away      L  0.0  2.0      Tottenham
# ..        ...    ...           ...  ...   ...    ...  ...  ...            ...
# 52 2023-05-06  15:00  Matchweek 35  Sat  Home      W  2.0  1.0   Leeds United
# 54 2023-05-14  14:00  Matchweek 36  Sun  Away      W  3.0  0.0        Everton
# 56 2023-05-21  16:00  Matchweek 37  Sun  Home      W  1.0  0.0        Chelsea
# 57 2023-05-24  20:00  Matchweek 32  Wed  Away      D  1.0  1.0       Brighton
# 58 2023-05-28  16:30  Matchweek 38  Sun  Away      L  0.0  1.0      Brentford
#
#      xg  ...  hour  day_code  gf_rolling ga_rolling sh_rolling sot_rolling  \
# 5   1.3  ...    17         5    2.000000   2.333333  17.333333    4.666667
# 7   1.0  ...    12         5    1.333333   2.000000  17.333333    3.666667
# 9   1.6  ...    12         5    1.000000   0.666667  16.666667    4.333333
# 11  1.4  ...    16         6    1.000000   0.333333  14.333333    6.666667
# 12  1.4  ...    17         5    1.000000   0.666667  12.000000    5.666667
# ..  ...  ...   ...       ...         ...        ...        ...         ...
# 52  2.6  ...    15         5    3.000000   0.666667  13.666667    8.000000
# 54  0.8  ...    14         6    2.333333   0.666667  14.666667    7.000000
# 56  1.2  ...    16         6    2.666667   0.333333  14.000000    5.666667
# 57  1.8  ...    20         2    2.000000   0.333333  13.666667    4.000000
# 58  1.6  ...    16         6    1.666667   0.333333  12.333333    3.333333
#
#    dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 5     19.700000    1.333333    0.333333       0.333333
# 7     18.566667    0.666667    0.000000       0.000000
# 9     18.933333    0.666667    0.000000       0.000000
# 11    19.033333    1.000000    0.000000       0.000000
# 12    20.000000    1.000000    0.000000       0.333333
# ..          ...         ...         ...            ...
# 52    15.433333    0.000000    0.333333       0.333333
# 54    16.366667    0.666667    0.333333       0.666667
# 56    18.100000    1.333333    0.000000       0.333333
# 57    18.933333    1.333333    0.000000       0.333333
# 58    17.333333    0.666667    0.000000       0.000000
#
# [111 rows x 38 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time         round  day venue result  \
# team
# Arsenal                 6  2020-10-04  14:00   Matchweek 4  Sun  Home      W
#                         7  2020-10-17  17:30   Matchweek 5  Sat  Away      L
#                         9  2020-10-25  19:15   Matchweek 6  Sun  Home      L
#                         11 2020-11-01  16:30   Matchweek 7  Sun  Away      W
#                         13 2020-11-08  19:15   Matchweek 8  Sun  Home      L
# ...                               ...    ...           ...  ...   ...    ...
# Wolverhampton Wanderers 39 2023-04-29  15:00  Matchweek 34  Sat  Away      L
#                         40 2023-05-06  15:00  Matchweek 35  Sat  Home      W
#                         41 2023-05-13  15:00  Matchweek 36  Sat  Away      L
#                         42 2023-05-20  15:00  Matchweek 37  Sat  Home      D
#                         43 2023-05-28  16:30  Matchweek 38  Sun  Away      L
#
#                              gf   ga         opponent   xg  ...  hour  \
# team                                                        ...
# Arsenal                 6   2.0  1.0    Sheffield Utd  0.6  ...    14
#                         7   0.0  1.0  Manchester City  0.9  ...    17
#                         9   0.0  1.0   Leicester City  0.7  ...    19
#                         11  1.0  0.0   Manchester Utd  1.0  ...    16
#                         13  0.0  3.0      Aston Villa  1.5  ...    19
# ...                         ...  ...              ...  ...  ...   ...
# Wolverhampton Wanderers 39  0.0  6.0         Brighton  0.8  ...    15
#                         40  1.0  0.0      Aston Villa  0.8  ...    15
#                         41  0.0  2.0   Manchester Utd  0.3  ...    15
#                         42  1.0  1.0          Everton  1.6  ...    15
#                         43  0.0  5.0          Arsenal  0.5  ...    16
#
#                             day_code  gf_rolling ga_rolling sh_rolling  \
# team
# Arsenal                 6          6    2.000000   1.333333   8.000000
#                         7          5    1.666667   1.666667   5.666667
#                         9          6    1.000000   1.666667   7.000000
#                         11         6    0.666667   1.000000   9.666667
#                         13         6    0.333333   0.666667   9.666667
# ...                              ...         ...        ...        ...
# Wolverhampton Wanderers 39         5    1.666667   0.666667  11.666667
#                         40         5    1.000000   2.666667  11.333333
#                         41         5    1.000000   2.000000   8.000000
#                         42         5    0.333333   2.666667   7.000000
#                         43         6    0.666667   1.000000   8.000000
#
#                            sot_rolling dist_rolling  fk_rolling  pk_rolling  \
# team
# Arsenal                 6     3.666667    14.633333    0.666667    0.000000
#                         7     3.666667    15.366667    0.000000    0.000000
#                         9     3.666667    16.566667    0.666667    0.000000
#                         11    4.000000    16.566667    1.000000    0.000000
#                         13    2.666667    19.333333    1.000000    0.333333
# ...                                ...          ...         ...         ...
# Wolverhampton Wanderers 39    4.666667    18.700000    0.666667    0.333333
#                         40    2.333333    18.800000    0.666667    0.333333
#                         41    2.000000    17.766667    0.000000    0.333333
#                         42    1.333333    15.600000    0.000000    0.000000
#                         43    2.333333    15.333333    0.333333    0.000000
#
#                             pkatt_rolling
# team
# Arsenal                 6        0.000000
#                         7        0.000000
#                         9        0.000000
#                         11       0.000000
#                         13       0.333333
# ...                                   ...
# Wolverhampton Wanderers 39       0.333333
#                         40       0.333333
#                         41       0.333333
#                         42       0.000000
#                         43       0.000000
#
# [2202 rows x 38 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time         round  day venue result   gf   ga  \
# 6  2020-10-04  14:00   Matchweek 4  Sun  Home      W  2.0  1.0
# 7  2020-10-17  17:30   Matchweek 5  Sat  Away      L  0.0  1.0
# 9  2020-10-25  19:15   Matchweek 6  Sun  Home      L  0.0  1.0
# 11 2020-11-01  16:30   Matchweek 7  Sun  Away      W  1.0  0.0
# 13 2020-11-08  19:15   Matchweek 8  Sun  Home      L  0.0  3.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 39 2023-04-29  15:00  Matchweek 34  Sat  Away      L  0.0  6.0
# 40 2023-05-06  15:00  Matchweek 35  Sat  Home      W  1.0  0.0
# 41 2023-05-13  15:00  Matchweek 36  Sat  Away      L  0.0  2.0
# 42 2023-05-20  15:00  Matchweek 37  Sat  Home      D  1.0  1.0
# 43 2023-05-28  16:30  Matchweek 38  Sun  Away      L  0.0  5.0
#
#            opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# 6     Sheffield Utd  0.6  ...    14         6    2.000000   1.333333
# 7   Manchester City  0.9  ...    17         5    1.666667   1.666667
# 9    Leicester City  0.7  ...    19         6    1.000000   1.666667
# 11   Manchester Utd  1.0  ...    16         6    0.666667   1.000000
# 13      Aston Villa  1.5  ...    19         6    0.333333   0.666667
# ..              ...  ...  ...   ...       ...         ...        ...
# 39         Brighton  0.8  ...    15         5    1.666667   0.666667
# 40      Aston Villa  0.8  ...    15         5    1.000000   2.666667
# 41   Manchester Utd  0.3  ...    15         5    1.000000   2.000000
# 42          Everton  1.6  ...    15         5    0.333333   2.666667
# 43          Arsenal  0.5  ...    16         6    0.666667   1.000000
#
#    sh_rolling sot_rolling dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 6    8.000000    3.666667    14.633333    0.666667    0.000000       0.000000
# 7    5.666667    3.666667    15.366667    0.000000    0.000000       0.000000
# 9    7.000000    3.666667    16.566667    0.666667    0.000000       0.000000
# 11   9.666667    4.000000    16.566667    1.000000    0.000000       0.000000
# 13   9.666667    2.666667    19.333333    1.000000    0.333333       0.333333
# ..        ...         ...          ...         ...         ...            ...
# 39  11.666667    4.666667    18.700000    0.666667    0.333333       0.333333
# 40  11.333333    2.333333    18.800000    0.666667    0.333333       0.333333
# 41   8.000000    2.000000    17.766667    0.000000    0.333333       0.333333
# 42   7.000000    1.333333    15.600000    0.000000    0.000000       0.000000
# 43   8.000000    2.333333    15.333333    0.333333    0.000000       0.000000
#
# [2202 rows x 38 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] > '2023-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.5306122448979592

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted       date     team         opponent result
# 89       0          1 2023-01-03  Arsenal    Newcastle Utd      D
# 90       1          0 2023-01-15  Arsenal        Tottenham      W
# 91       1          0 2023-01-22  Arsenal   Manchester Utd      W
# 92       0          1 2023-02-04  Arsenal          Everton      L
# 93       0          1 2023-02-11  Arsenal        Brentford      D
# 94       0          0 2023-02-15  Arsenal  Manchester City      L
# 95       1          1 2023-02-18  Arsenal      Aston Villa      W
# 96       1          0 2023-02-25  Arsenal   Leicester City      W
# 97       1          0 2023-03-01  Arsenal          Everton      W
# 98       1          1 2023-03-04  Arsenal      Bournemouth      W

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           0            1 2023-01-03                  Arsenal
# 1           1            0 2023-01-15                  Arsenal
# 2           1            0 2023-01-22                  Arsenal
# 3           0            1 2023-02-04                  Arsenal
# 4           0            1 2023-02-11                  Arsenal
# ..        ...          ...        ...                      ...
# 402         0            0 2023-04-29  Wolverhampton Wanderers
# 403         1            0 2023-05-06  Wolverhampton Wanderers
# 404         0            0 2023-05-13  Wolverhampton Wanderers
# 405         0            0 2023-05-20  Wolverhampton Wanderers
# 406         0            0 2023-05-28  Wolverhampton Wanderers
#
#          opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0     Newcastle Utd        D    Arsenal         0            0
# 1         Tottenham        W    Arsenal         0            0
# 2    Manchester Utd        W    Arsenal         0            1
# 3           Everton        L    Arsenal         1            0
# 4         Brentford        D    Arsenal         0            0
# ..              ...      ...        ...       ...          ...
# 402        Brighton        L     Wolves         1            1
# 403     Aston Villa        W     Wolves         0            0
# 404  Manchester Utd        L     Wolves         1            1
# 405         Everton        D     Wolves         0            0
# 406         Arsenal        L     Wolves         1            0
#
#                        team_y opponent_y result_y      new_team_y
# 0            Newcastle United    Arsenal        D   Newcastle Utd
# 1           Tottenham Hotspur    Arsenal        L       Tottenham
# 2           Manchester United    Arsenal        L  Manchester Utd
# 3                     Everton    Arsenal        W         Everton
# 4                   Brentford    Arsenal        D       Brentford
# ..                        ...        ...      ...             ...
# 402  Brighton and Hove Albion     Wolves        W        Brighton
# 403               Aston Villa     Wolves        L     Aston Villa
# 404         Manchester United     Wolves        W  Manchester Utd
# 405                   Everton     Wolves        D         Everton
# 406                   Arsenal     Wolves        W         Arsenal
#
# [407 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    48
# 0    38
# Name: actual_x, dtype: int64
